# %% [markdown]
# 1. Análisis Exploratorio:
# Describir la serie de tiempo y visualizarla.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Carga el archivo CSV en un DataFrame de Pandas
df = pd.read_csv('daily-total-female-births.csv')

# Asegúrate de que la columna 'Date' se interprete como fechas
df['Date'] = pd.to_datetime(df['Date'])

# Muestra información básica sobre el DataFrame
print(df.info())

# Muestra estadísticas descriptivas de la columna 'Births'
print(df['Births'].describe())

# Configura el tamaño de la figura
plt.figure(figsize=(12, 6))

# Grafica la serie de tiempo
sns.set_style("darkgrid")
plt.plot(df['Date'], df['Births'], label='Nacimientos diarios', color='b')

# Configura etiquetas y título
plt.xlabel('Fecha')
plt.ylabel('Nacimientos')
plt.title('Nacimientos Diarios de Mujeres')

# Rota las etiquetas del eje x para una mejor legibilidad
plt.xticks(rotation=45)

# Muestra la leyenda
plt.legend()

# Muestra el gráfico
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365 entries, 0 to 364
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    365 non-null    datetime64[ns]
#  1   Births  365 non-null    int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 5.8 KB
# None
# count    365.000000
# mean      41.980822
# std        7.348257
# min       23.000000
# 25%       37.000000
# 50%       42.000000
# 75%       46.000000
# max       73.000000
# Name: Births, dtype: float64
